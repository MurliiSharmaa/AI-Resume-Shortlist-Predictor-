# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)

# %%
#AIzaSyAP-7vsRmw0NxVC1E9PVFd_MTk5XHgDsO4

# %%
import google.generativeai as genai
import PyPDF2 as pdf
import json

# %%
genai.configure(api_key="AIzaSyAP-7vsRmw0NxVC1E9PVFd_MTk5XHgDsO4")

# %%
def get_gemini_repsonse(input):
    model=genai.GenerativeModel('gemini-pro')
    response=model.generate_content(input)
    return response.text
def input_pdf_text(uploaded_file):
    reader=pdf.PdfReader(uploaded_file)
    text=""
    for page in range(len(reader.pages)):
        page=reader.pages[page]
        text+=str(page.extract_text())
    return text

# %%
def build_prompt(text, jd):
  input_prompt=f"""
  Hello Act Like a very skilled or very experience Resume Reviewer
  with a deep understanding of tech field,software engineering,data science ,data analyst
  and big data engineer. Your task is to evaluate the resume based on the given job description.
  You must consider the job market is very competitive and you should provide
  best assistance for improving the resumes. Assign the percentage Matching based
  on JD and a summary of the resume profile and
  the suggestions to improve the resume with high accuracy
  resume:{text}
  description:{jd}
  I want the response in one single string having the structure {{"JD Match":"%","Profile Summary":"", "Suggestions:[]"}} """
  return input_prompt

# %%
text=input_pdf_text("/content/Resume_Dummy.pdf")

# %%
jd = input("Enter the Job Description")
# Out:
# Enter the Job DescriptionAs a Data Analyst Intern at Unified Mentor, you will have the opportunity to gain hands-on experience in data analysis and contribute to real-world projects. This internship is designed to provide valuable insights and skills in data analytics, enhancing your career prospects in this field.   Responsibilities: Assist in collecting, cleaning, and analyzing data sets. Collaborate with the data analysis team to identify trends and patterns. Contribute to the development of data visualization dashboards and reports. Support in creating presentations to communicate findings to stakeholders. Learn and utilize various data analysis tools and techniques.

# %%
input_prompt = build_prompt(text, jd)

# %%
response=get_gemini_repsonse(input_prompt)
response=get_gemini_repsonse(input_prompt)
response = json.loads(response)

# %%
import textwrap


def add_newlines(text):
    sentences = text.split('. ')
    return '.\n'.join(sentences) + '.\n'

def print_response(response):
    print("JD Match: {}\n".format(response["JD Match"]))
    print("Profile Summary:\n{}\n".format(add_newlines(response["Profile Summary"])))
    print("Suggestions:")
    for suggestion in response["Suggestions"]:
        print("- {}".format(add_newlines(suggestion)))

print_response(response)
# Out:
# JD Match: 70%
#
# Profile Summary:
# The resume demonstrates strong technical skills and experience in data analysis, software engineering, and machine learning.
# However, the work experience section needs more details and quantifiable results to showcase the candidate's impact and contributions..
#
#
# Suggestions:
# - Highlight relevant coursework or projects in data analysis or machine learning in the education section to align with the internship responsibilities..
#
# - Expand on the work experience at Tata Consultancy Services to include specific metrics or achievements related to data analysis tasks..
#
# - Include a separate section for data analysis tools and techniques used, such as statistical software, data visualization tools, and machine learning libraries..
#
# - Consider including a portfolio or GitHub link to showcase personal projects or contributions in data analysis or machine learning..
#
# - Tailor the resume specifically to the data analyst intern role by highlighting transferable skills and experiences that correlate with the responsibilities outlined in the job description..
